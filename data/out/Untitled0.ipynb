# %%
import healpy as h

# %%
cl1=h.read_cl("clin_cl_nrlz1.fits")

# %%
cl2=h.read_cl("../in/clmd.fits")
cl3=h.read_cl("../in/cld.fits")

# %%
plot(cl1,"b-")
plot(cl2,"r-")
plot(cl3,"g-")
loglog()
# Out:
# []
